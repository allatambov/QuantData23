# %% [markdown]
# # Основы работы с количественными данными <br> Домашнее задание №1
#
# *Преподаватель: Алла Тамбовцева*

# %% [markdown]
# *Всего за домашнее задание можно набрать 35 баллов, для оценки 10 нужно предложить корректное и подробное решение задачи №4.*

# %% [markdown]
# ### Формат сдачи
#
# Для выполнения задания необходимо скачать текущий ipynb-файл, вписать в него ответы и решения, а также код для практических задач, сохранить изменения и загрузить обновленный файл на Dropbox по предложенной на странице курса ссылке. Иметь аккаунт Dropbox для этого не требуется, достаточно пройти по ссылке и выбрать файл на компьютере.
#
# Как загрузить ipynb-файл для того, чтобы вписать в него решения:
#
# * **Google Colab:** выбрать пункт меню *File → Upload notebook*, выбрать скачанный ipynb-файл на компьютере, подтвердить его загрузку;
# * **Jupyter Notebook:** в *Home Page* кликнуть на *Upload*, выбрать скачанный ipynb-файл, кликнуть еще раз на *Upload* для подтверждения загрузки.
#
# Как скачать отредактированный ipynb-файл после сохранения решений:
#
# * **Google Colab:** выбрать пункт меню *File → Download → Download .ipynb*
# * **Jupyter Notebook:** выбрать пункт меню *File → Download as... → Notebook (.ipynb)*.

# %% [markdown]
# ### Задача 1 (5 баллов)
#
# Укажите шкалы следующих показателей (абсолютная, интервальная, порядковая, номинальная):
#
# * Уровень образования (начальное, среднее, высшее);
# * Объём продаж фирмы (в тысячах изделий);
# * Членство страны в ОПЕК (да/нет);
# * Индекс человеческого развития (значения от 0 до 1);
# * Затраты на инновационную деятельность малых предприятий (в миллионах рублей).

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задача 2 (4 балла)
#
# В этом задании вам предлагается поработать с [материалами](https://freedomhouse.org/reports/freedom-world/freedom-world-research-methodology) по методологии индекса политических прав и гражданских свобод от Freedom House (*Freedom in the World*).
#
# **2.1.** Чему равны минимально и максимально возможные значения индекса политических прав (*Political Rights*), который входит в итоговый индекс *Freedom in the World*?
#
# **2.2.** Значение индекса гражданских свобод (*Civil Liberties*) для некоторой страны равно 20. Значение индекса политических свобод (*Political Rights*) для этой страны равно 10. Каков статус этой страны (*FREE*, *PARTLY FREE*, *NOT FREE*)?

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задача 3 (6 баллов)
#
# Приведите пример:
#
# 1. выборки из 7 наблюдений, для которой размах равен 0;
# 2. выборки из 10 наблюдений, для которой размах и межквартильный размах совпадают;
# 3. выборки из 9 наблюдений, для которой нижний квартиль и медиана совпадают.

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задача 4 (10 баллов)
#
# Дана выборка из целых чисел:
#
# $$
# 5, \mbox{ }x_1,\mbox{ } x_2,\mbox{ } 5,\mbox{ } 10.
# $$
# Найдите $x_1$ и $x_2$, если известно, что $x_2>x_1>5$, среднее выборки равно 10, а размах равен 15. Приведите подробное решение, которое раскрывает ход ваших мыслей при поиске значений.

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задача 5 (10 баллов)
#
# В таблице представлены значения индекса эффективного числа партий Лааксо-Таагеперы для некоторого числа стран за 2015 год (значения округлены до целых чисел):
#
# | Страна  | Индекс | Страна | Индекс |
# |----------------|-----------------|-----------------|-----------------|
# | Австралия      | 4               | Латвия          | 6               |
# | Австрия        | 5               | Литва           | 8               |
# | Бельгия        | 10              | Люксембург      | 5               |
# | Великобритания | 4               | Мальта          | 2               |
# | Венгрия        | 3               | Португалия      | 3               |
# | Дания          | 6               | Чехия           | 10              |

# %% [markdown]
# В массиве `LT` сохранены значения индекса из таблицы выше:

# %%
import numpy as np

LT = np.array([4, 5, 10, 4, 3, 6, 6, 8, 5, 2, 3, 10])
LT

# %% [markdown]
# Используя функции из `numpy`, для представленной выборки найдите:
#
# * минимальное и максимальное значение;
# * размах;
# * среднее арифметическое;
# * медиану;
# * нижний и верхний квартили;
# * межквартильный размах.

# %%
# здесь можете создать несколько ячеек с кодом
