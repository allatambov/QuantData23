# %% [markdown]
# # Основы работы с количественными данными
# ## Домашнее задание №4
#
# *Преподаватель: Алла Тамбовцева*
#
# *Всего за домашнее задание можно набрать 20 баллов.*
#
# ### Формат сдачи
#
# Для выполнения задания необходимо скачать текущий ipynb-файл, вписать в него ответы и решения, а также код для практических задач, сохранить изменения и загрузить обновленный файл на Dropbox по предложенной на странице курса ссылке. Иметь аккаунт Dropbox для этого не требуется, достаточно пройти по ссылке и выбрать файл на компьютере.
#
# Как загрузить ipynb-файл для того, чтобы вписать в него решения:
#
# * **Google Colab:** выбрать пункт меню *File → Upload notebook*, выбрать скачанный ipynb-файл на компьютере, подтвердить его загрузку;
#
# * **Jupyter Notebook:** в *Home Page* кликнуть на *Upload*, выбрать скачанный ipynb-файл, кликнуть еще раз на *Upload* для подтверждения загрузки.
#
# Как скачать отредактированный ipynb-файл после сохранения решений:
#
# * **Google Colab:** выбрать пункт меню *File → Download → Download .ipynb*.
# * **Jupyter Notebook:** выбрать пункт меню *File → Download as... → Notebook (.ipynb)*.

# %% [markdown]
# ### Теоретическая часть

# %% [markdown]
# ### Задача 1 (3 балла)
#
# По каждой представленной диаграмме рассеивания опишите характер связи между показателями $X$ и $Y$ (линейность/нелинейность связи, сила и направление связи, наличие/отсутствие выбросов). Укажите, какой коэффициент корреляции, Пирсона или Спирмена, лучше использовать в каждом случае.
#
# ![1](https://raw.githubusercontent.com/allatambov/QuantData23/main/scatter1.png)
# ![3](https://raw.githubusercontent.com/allatambov/QuantData23/main/scatter3.png)
# ![7](https://raw.githubusercontent.com/allatambov/QuantData23/main/scatter7.png)

# %% [markdown]
# ОТВЕТ

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Какие из утверждений о коэффициенте Пирсона является/являются верными?
#
# A.  Значение коэффициента 0.2 означает, что 20\% наблюдений сильно скоррелированы.
#
# B. Идеальная линейная корреляция, когда точки на диаграмме рассеяния лежат ровно на одной прямой, выражается в коэффициенте $r=0$.
#
# C.  Значение коэффициента корреляции не зависит от того, какой из показателей при вычислении стоит на первом месте, а какой — на втором.
#
# D. Значение коэффициента корреляции подвержено влиянию нетипичных наблюдений.
#
# E.  Значение коэффициента корреляции 0.75 означает, что отношение между показателями в три раза более линейное, чем отношение между показателями с коэффициентом корреляции 0.25.

# %% [markdown]
# ОТВЕТ

# %% [markdown]
# ### Практическая часть
#
# В файле `coffee_and_code.csv` содержатся результаты опроса программистов:
#
# * `CodingHours` : время, которое респондент тратит на написание кода (число часов в день);
# * `CoffeeCupsPerDay`: количество чашек кофе, которое респондент выпивает в день;
# * `CoffeeTime`: когда респондент пьет кофе (перед написанием кода, во время написания кода, весь день и прочие варианты);
# * `CodingWithoutCoffee`: пишет ли респондент код без кофе (да, нет, иногда);
# * `CoffeeType`: тип или марка кофе, предпочитаемые респондентом;
# * `CoffeeSolveBugs`: исправляет ли программист баги в коде (да, нет, иногда);
# * `Gender`: пол респондента;
# * `Country`: страна респондента;
# * `AgeRange`: возраст респондента (по категориям).
#
# Загрузите данные из файла и выполните следующие задания.

# %%
# код, можете добавить несколько ячеек

# %% [markdown]
# ### Задача 3 (3 балла)
#
# **(1 балл)** Постройте диаграмму рассеивания между показателями `CodingHours` и `CoffeeCupsPerDay`.

# %%
# код, можете добавить несколько ячеек

# %% [markdown]
# **3.1 (1 балл)** Прокомментируйте полученный график: укажите, что можно сказать о направлении и силе связи между этими переменными.
#
# **3.2 (1 балл)** Кажется ли вам характер связи логичным? Прокомментируйте.

# %% [markdown]
# ОТВЕТ

# %% [markdown]
# ### Задача 4 (7 баллов)
#
# Учитывая тип данных и их совместное распределение (диаграмму рассеивания в предыдущей задаче), выберите подходящую меру связи между показателями `CodingHours` и `CoffeeCupsPerDay` и проверьте соответствующую гипотезу, приняв уровень значимости равным 5%.
#
# **4.1. (1 балл)** Укажите подходящую меру для оценки связи между показателями. Обоснуйте свой ответ.
#
# **4.2. (1 балл)** Сформулируйте нулевую гипотезу и альтернативную гипотезу.
#
# ОТВЕТ

# %% [markdown]
# **4.3. (2 балла)** Вычислите в Python подходящую меру связи и проверьте сформулированную нулевую гипотезу.

# %%
# код, можете добавить несколько ячеек

# %% [markdown]
# **4.4. (1 балл)** Проинтерпретируйте полученное значение меры связи (связь прямая или обратная, слабая или сильная).
#
# **4.5. (2 балла)** Сделайте статистический и содержательный вывод относительно нулевой гипотезы.
#
# ОТВЕТ

# %% [markdown]
# ### Задача 5 (5 баллов)
#
# Представьте, что вам необходимо проверить, есть ли связь между полом программиста (`Gender`) и тем, насколько часто он/она исправляет баги в коде (`CoffeeSolveBugs`). Выберите подходящую меру связи между показателями и проверьте соответствующую гипотезу, приняв уровень значимости равным 5%.
#
# **5.1. (1 балл)** Укажите подходящую меру для оценки связи между показателями. Обоснуйте свой ответ.
#
# **5.2. (1 балл)** Сформулируйте нулевую гипотезу и альтернативную гипотезу.
#
# ОТВЕТ
#
# **5.3. (2 балла)** Реализуйте в Python необходимые шаги для проверки гипотезы.

# %%
# код, можете добавить несколько ячеек

# %% [markdown]
# **5.4. (1 балл)** Сделайте статистический и содержательный вывод относительно нулевой гипотезы.
#
# ОТВЕТ
