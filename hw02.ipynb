# %% [markdown]
# # Основы работы с количественными данными <br> Домашнее задание №2
#
# *Преподаватель: Алла Тамбовцева*

# %% [markdown]
# *Всего за домашнее задание можно набрать 40 баллов, для оценки 10 нужно предложить корректное и подробное решение задачи №5.*

# %% [markdown]
# ### Формат сдачи
#
# Для выполнения задания необходимо скачать текущий ipynb-файл, вписать в него ответы и решения, а также код для практических задач, сохранить изменения и загрузить обновленный файл на Dropbox по предложенной на странице курса ссылке. Иметь аккаунт Dropbox для этого не требуется, достаточно пройти по ссылке и выбрать файл на компьютере.
#
# Как загрузить ipynb-файл для того, чтобы вписать в него решения:
#
# * **Google Colab:** выбрать пункт меню *File → Upload notebook*, выбрать скачанный ipynb-файл на компьютере, подтвердить его загрузку;
# * **Jupyter Notebook:** в *Home Page* кликнуть на *Upload*, выбрать скачанный ipynb-файл, кликнуть еще раз на *Upload* для подтверждения загрузки.
#
# Как скачать отредактированный ipynb-файл после сохранения решений:
#
# * **Google Colab:** выбрать пункт меню *File → Download → Download .ipynb*
# * **Jupyter Notebook:** выбрать пункт меню *File → Download as... → Notebook (.ipynb)*.

# %% [markdown]
# *Всего за домашнее задание можно набрать 35 баллов, для оценки 10 нужно предложить корректное и подробное решение задачи №5.*

# %% [markdown]
# ### Задание 1 (4 балла)
#
# Для некоторой выборки была построена гистограмма:
#
# ![hist01](https://raw.githubusercontent.com/allatambov/QuantData23/main/hist01.png)
#
# Выберите все верные утверждения.
#
# * A. Распределение показателя скошено влево.
# * B. Распределение показателя скошено вправо.
# * C. Распределение показателя является симметричным.
# * D. Медиана выборки больше среднего выборки.
# * E. Медиана выборки меньше среднего выборки.
# * F. Значения на отрезке [0; 1] встречаются чаще, чем значения на отрезке [2; 3].
# * G. Значения на отрезке [-1; 0] встречаются реже, чем значения на отрезке [1; 2].
# * H. Медиана показателя может находиться на отрезке [-1; 0].
# * I. Медиана показателя может находиться на отрезке [-3;-2].

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 2 (4 балла)
#
# **2.1. (2 балла)** Для двух выборок построили гистограммы. Какая из выборок, первая или вторая, имеет большую дисперсию? Объясните свой ответ.
#
# ![](https://raw.githubusercontent.com/allatambov/QuantData23/main/1.png)
#
#
# **2.2. (2 балла)** Для двух выборок построили гистограммы. Какая из выборок, первая или вторая, имеет большую дисперсию? Объясните свой ответ.
#
# ![](https://raw.githubusercontent.com/allatambov/QuantData23/main/2.png)

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 3 (4 балла)
#
# Для показателя *Индекс подготовленности судьи к судебному процессу* (экспертный индекс, построенный на оценках адвокатов, в шкале от 1 до 10, где 10 соответствует лучшей подготовленности) был построен ящик с усами:
#
# ![law](https://raw.githubusercontent.com/allatambov/QuantData23/main/box-law.png)
#
# Проинтерпретируйте полученный график. Ваша интерпретация должна включать:
# информацию о симметрии/скошенности распределения;
# примерные значения описательных статистик, которые можно вынести из графика, и пояснения к ним; наличие/отсутствие нетипичных значений.

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 4 (4 балла)
#
# Для четырех выборок были построены ящики с усами и гистограммы. Затем подписи стёрли, а графики перемешали. Соедините гистограммы и ящики с усами, которые соответствуют одним и тем же выборкам (должно получиться 4 пары).
#
# ![](https://raw.githubusercontent.com/allatambov/QuantData23/main/hists.png)
# ![](https://raw.githubusercontent.com/allatambov/QuantData23/main/boxs.png)

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 5 (10 баллов)
#
# Дана выборка:
#
# $$
# 1, x_1, 4, 5, x_2.
# $$
#
# Найдите $x_1$ и $x_2$, если известно, что $x_1 + x_2$ = 10, среднее выборки равно 4 и выборочная дисперсия (формула с $n-1$ в знаменателе, они бывают разные) равна 5. Приведите подробное решение. Можно приложить ссылку на фото/скан решения, возможно, написать от руки будет удобнее. Также можно отдать листок с решением на занятии.

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 6 (4 балла)
#
# Исследователь случайным образом выбрал 10 сотрудников фирмы $A$ и 10 сотрудников фирмы $B$ и зафиксировал их заработную плату, данные приведены ниже (сохранены в массивы).

# %%
import numpy as np

A = np.array([10000, 15000, 10000, 80000, 20000, 10000, 8000, 35000, 22000, 12000])
B = np.array([8000, 10000, 12000, 15000, 10000, 9000, 8000, 11000, 10000, 1000])

# %% [markdown]
# **6.1. (2 балла)** В какой компании средняя заработная плата сотрудников выше? Приведите код, посчитанные средние значения и ответ на вопрос.

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# **6.2. (2 балла)** В какой компании заработную плату можно считать более дифференцированной? Сделайте вывод на основе посчитанных стандартных отклонений выборки. Приведите код, посчитанные стандартные отклонения и ответ на вопрос.
#
# **Подсказка:** по аналогии с функциями для среднего или медианы, из `np` можно вызвать функцию `std()` для вычисления стандартных отклонений.

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 7 (10 баллов)
#
# В файле `wgidataset.xlsx` хранятся данные по индексам *Worldwide Governance Indicators* от Всемирного банка за 2021 год. Большие значения индексов означают лучшее качество (большую стабильность, лучшее качество государственного управления, более высокие оценки верховенства закона и так далее).
#
# Столбцы в таблице:
#
# * `Country/Territory`: страна;
# * `Code`: код страны;
# * `VoiceAccount`: индекс подотчётности государственных органов *Voice and Accountability*;
# * `PolStability`: индекс политической стабильности *Political Stability and Absence of Violence*;
# * `GovEffect`: индекс эффективности работы правительства *Government Effectivenss*;
# * `RegQual`: индекс качества законодательства *Regulatory Quality*;
# * `RuleLaw`: индекс верховенства закона *Rule of Law*;
# * `ContCorr`: индекс сдерживания коррупции *Control of Corruption*;
# * `Region`: регион.

# %% [markdown]
# Загрузите файл с данными в *Google Colab* или *Jupyter*, считайте данные с помощью `pandas` и сохраните их в датафрейм `df`.

# %%
import pandas as pd
df = pd.read_excel("/content/wgidataset.xlsx") # для Colab

# %% [markdown]
# **7.1. (1 балл)** Выведите описательные статистики для столбца `GovEffect`. Проинтерпретируйте полученные значения.

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# **7.2. (3 балла)** Постройте гистограммы для показателей `VoiceAccount`, `GovEffect`, `ContCorr`. Всего должно получиться три гистограммы. Измените цвет заливки гистограмм. Прокомментируйте форму каждого из распределений (скошенное или симметричное, если скошенное, то в какую сторону, какие значения встречаются чаще, а какие – реже).

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# **7.3. (2 балла)** Выведите на экран таблицу частот для значений столбца `Region` (из выдачи должно быть понятно, какие регионы есть в файле с данными и сколько стран относится к каждому региону).

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# **7.4. (2 баллов)** Для каждого региона вычислите среднее и стандартное отклонение числовых индексов.

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# **7.5. (2 балла)** Для каждого региона вычислите минимальное и максимальное значение числовых индексов.

# %%
# добавьте ячейки с кодом и не забудьте дать 
# содержательный ответ на вопрос в ячейке со словом ОТВЕТ

# %% [markdown]
# **ОТВЕТ**
